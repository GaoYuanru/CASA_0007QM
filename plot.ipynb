# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

import numpy as np

import sklearn
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix

import matplotlib.pyplot as plt
import seaborn as sn
internet = pd.read_csv('vif_new_try.csv')

# %%
import csv
from collections import Counter

with open('vif_new.csv', 'r') as f:
    reader = csv.reader(f)
    next(reader)  # 跳过表头
    data = [row[4] for row in reader]
    counts = Counter(data)
print(counts)
# Out:
# Counter({'3.0': 243, '4.0': 210, '2.0': 208, '5.0': 182, '6.0': 137, '1.0': 107, '7.0': 107, '8.0': 63, '9.0': 31, '10.0': 20, '11.0': 6, '12.0': 2, '13.0': 1, '15.0': 1})

# %%
#pip install matplotlib


import matplotlib.pyplot as plt

#plt.pie(counts.values(), labels=counts.keys())
#plt.pie(counts.values(), labels=counts.keys(),autopct='%1.1f%%',startangle=90,shadow=True,radius=2)

plt.pie(counts.values(),radius=2.5, labels=counts.keys(),autopct=lambda p : '{:.1f}%  ({:,.0f})'.format(p,(p/100)*sum(counts.values())))
#plt.show()
plt.legend(counts.keys(), bbox_to_anchor=(2.5, 1.5))
plt.show()

# %%
import pandas as pd

#df = pd.read_csv('data.csv')

# 计算描述性统计量
print(internet.describe())
sns.distplot(internet["all25_bbn"])
plt.show()
# Out:
#          population        unemp   health_ins      poverty         SNAP  \
# count  1.318000e+03  1318.000000  1318.000000  1318.000000  1318.000000
# mean   1.317965e+05     3.880121     9.875341    15.474962    13.055766
# std    4.113116e+05     1.355626     4.982529     6.379867     6.218528
# min    2.720000e+02     1.400000     1.800000     3.500000     0.000000
# 25%    1.368325e+04     2.900000     6.025000    10.900000     8.500000
# 50%    3.065400e+04     3.600000     8.900000    14.600000    12.100000
# 75%    9.299825e+04     4.500000    12.400000    18.800000    16.700000
# max    1.003911e+07    16.400000    39.200000    48.300000    41.800000
#
#            no_comp  no_internet   home_broad    broad_num  broad_avail  ...  \
# count  1318.000000  1318.000000  1318.000000  1318.000000  1318.000000  ...
# mean     15.957815    25.817223    73.476707     4.305008    75.675948  ...
# std       6.940948     9.237602     9.327403     2.261457    22.642548  ...
# ...
